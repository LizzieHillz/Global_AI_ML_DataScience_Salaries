# %% [markdown]
# ## DATA CLEANING

# %%
#Importing the necesssary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset
df = pd.read_csv(r"C:\Users\USER\Documents\Courses\Visiola_Foundation\Project/global_ai_ml_data_salaries.csv")

# %%
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               SE              FT              Data Analyst
# 1           2024               SE              FT              Data Analyst
# 2           2024               EX              FT         Software Engineer
# 3           2024               EX              FT         Software Engineer
# 4           2024               MI              FT              Data Manager
# ...          ...              ...             ...                       ...
# 25755       2020               SE              FT            Data Scientist
# 25756       2021               MI              FT  Principal Data Scientist
# 25757       2020               EN              FT            Data Scientist
# 25758       2020               EN              CT     Business Data Analyst
# 25759       2021               SE              FT            Data Scientist
#
# ...

# %%
#Calling the first 10 of the dataset
df.head(10)
# Out:
#    work_year experience_level employment_type          job_title  salary  \
# 0       2024               SE              FT       Data Analyst  120000
# 1       2024               SE              FT       Data Analyst   80000
# 2       2024               EX              FT  Software Engineer  243300
# 3       2024               EX              FT  Software Engineer  131500
# 4       2024               MI              FT       Data Manager   50000
# 5       2024               MI              FT       Data Manager   45000
# 6       2024               MI              FT  Applied Scientist  159600
# 7       2024               MI              FT  Applied Scientist   83600
# 8       2024               SE              FT  Software Engineer  284000
# 9       2024               SE              FT  Software Engineer  189000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         120000                 US             0
# ...

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  25760.000000  2.576000e+04   25760.000000  25760.000000
# mean    2023.503494  1.622532e+05  153146.139325     27.001165
# std        0.681446  2.760921e+05   68654.598096     44.117813
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.050000e+05  105000.000000      0.000000
# 50%     2024.000000  1.450000e+05  145000.000000      0.000000
# 75%     2024.000000  1.935000e+05  192312.750000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
#Getting the information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25760 entries, 0 to 25759
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           25760 non-null  int64
#  1   experience_level    25760 non-null  object
#  2   employment_type     25760 non-null  object
#  3   job_title           25760 non-null  object
#  4   salary              25760 non-null  int64
#  5   salary_currency     25760 non-null  object
#  6   salary_in_usd       25760 non-null  int64
#  7   employee_residence  25760 non-null  object
#  8   remote_ratio        25760 non-null  int64
#  9   company_location    25760 non-null  object
#  10  company_size        25760 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 2.2+ MB

# %%
#Checking for null values
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Checking for duplicate values
df.duplicated().sum()
# Out:
# 11485

# %%
#Dropping duplicate values
df = df.drop_duplicates(keep = 'first')
#Checking if the duplicate values dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14275 entries, 0 to 25759
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14275 non-null  int64
#  1   experience_level    14275 non-null  object
#  2   employment_type     14275 non-null  object
#  3   job_title           14275 non-null  object
#  4   salary              14275 non-null  int64
#  5   salary_currency     14275 non-null  object
#  6   salary_in_usd       14275 non-null  int64
#  7   employee_residence  14275 non-null  object
#  8   remote_ratio        14275 non-null  int64
#  9   company_location    14275 non-null  object
#  10  company_size        14275 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.3+ MB

# %%
#Getting Distinct Job titles
distinct_job_title = df['job_title'].unique()
distinct_job_title
# Out:
# array(['Data Analyst', 'Software Engineer', 'Data Manager',
#        'Applied Scientist', 'Machine Learning Engineer', 'Data Scientist',
#        'Data Engineer', 'AI Engineer', 'Engineering Manager',
#        'Software Developer', 'Research Scientist',
#        'Business Intelligence Engineer', 'Statistical Programmer',
#        'Analytics Engineer', 'Data Architect',
#        'Data Management Specialist', 'Head of AI',
#        'Data Governance Engineer', 'AI Research Scientist',
#        'Machine Learning Model Engineer', 'Data Specialist',
#        'Insight Analyst', 'Artificial Intelligence Engineer', 'Data Lead',
#        'Principal Statistical Programmer',
#        'Business Intelligence Developer', 'Machine Learning Manager',
#        'AI Architect', 'MLOps Engineer', 'ML Infrastructure Engineer',
#        'Business Intelligence Analyst', 'Backend Engineer',
#        'Data Governance Lead', 'Machine Learning Scientist',
# ...

# %%
# Define the mapping dictionary
job_title_mapping = {
    'Data Scientist': 'Data Science',
    'Machine Learning Engineer': 'Machine Learning',
    'AI Engineer': 'AI',
    'Data Analyst': 'Data Science',
    'Business Intelligence Analyst': 'Data Science',
    'Data Engineer': 'Data Science',
    'Research Scientist': 'AI',
    'AI Researcher': 'AI',
    'Deep Learning Engineer': 'AI',
    'Full Stack Engineer': 'Other',
    'Business Intelligence Engineer': 'Data Science',
    'Analytics Engineer': 'Data Science',
    'Applied Scientist': 'AI',
    'Data Quality Manager': 'Data Science',
    'Data Visualization Specialist': 'Data Science',
    'Software Development Engineer': 'Other',
    'Research Analyst': 'Data Science',
    'Systems Engineer': 'Other',
    'Software Engineer': 'Other',
    'Head of Data': 'Data Science',
    'DevOps Engineer': 'Other',
    'Data Analytics Specialist': 'Data Science',
    'Machine Learning Scientist': 'Machine Learning',
    'Data Team Lead': 'Data Science',
    'Robotics Engineer': 'AI',
    'Data Governance Lead': 'Data Science',
    'Site Reliability Engineer': 'Other',
    'Data Governance Analyst': 'Data Science',
    'Prompt Engineer': 'Other',
    'Data Specialist': 'Data Science',
    'Data Architect': 'Data Science',
    'Engineering Manager': 'Other',
    'Bear Robotics': 'Other',
    'Business Intelligence Developer': 'Data Science',
    'Data Management Lead': 'Data Science',
    'BI Developer': 'Data Science',
    'Backend Engineer': 'Other',
    'AI Specialist': 'AI',
    'Data Operations Analyst': 'Data Science',
    'AI Scientist': 'AI',
    'Machine Learning Developer': 'Machine Learning',
    'BI Engineer': 'Data Science',
    'Business Analyst': 'Data Science',
    'Frontend Engineer': 'Other',
    'Solutions Engineer': 'Other',
    'AI Developer': 'AI',
    'Insight Analyst': 'Data Science',
    'BI Analyst': 'Data Science',
    'Data Analytics Lead': 'Data Science',
    'Data Analytics Manager': 'Data Science',
    'Data Governance Manager': 'Data Science',
    'Solutions Architect': 'Other',
    'Data Product Manager': 'Data Science',
    'Quantitative Researcher': 'Data Science',
    'Data Analytics Team Lead': 'Data Science',
    'Data Lead': 'Data Science',
    'Software Developer': 'Other',
    'Data Manager': 'Data Science',
    'Machine Learning Platform Engineer': 'Machine Learning',
    'Principal Statistical Programmer': 'Other',
    'Data Management Analyst': 'Data Science',
    'Research Engineer': 'Other',
    'Data Governance Specialist': 'Data Science',
    'Statistical Programmer': 'Other',
    'Head of AI': 'AI',
    'Data Management Manager': 'Data Science',
    'Data Governance Engineer': 'Data Science',
    'Data Management Specialist': 'Data Science',
    'Machine Learning Model Engineer': 'Machine Learning',
    'Artificial Intelligence Engineer': 'AI',
    'Machine Learning Manager': 'Machine Learning',
    'AI Architect': 'AI',
    'MLOps Engineer': 'Machine Learning',
    'ML Infrastructure Engineer': 'Machine Learning',
    'Data Quality Analyst': 'Data Science',
    'Cloud Database Administrator': 'Other',
    'Computer Vision Engineer': 'AI',
    'Data Strategist': 'Data Science',
    'Data Integration Engineer': 'Data Science',
    'Decision Scientist': 'Data Science',
    'Data Quality Engineer': 'Data Science',
    'Data Modeler': 'Data Science',
    'Python Developer': 'Other',
    'Data Operations Engineer': 'Data Science',
    'Data Infrastructure Engineer': 'Data Science',
    'Data Operations Specialist': 'Data Science',
    'Business Intelligence': 'Data Science',
    'Data Visualization Analyst': 'Data Science',
    'Machine Learning Architect': 'Machine Learning',
    'Data Product Owner': 'Data Science',
    'Machine Learning Modeler': 'Machine Learning',
    'Machine Learning Quality Engineer': 'Machine Learning',
    'Data Integration Coordinator': 'Data Science',
    'Data Integration Analyst': 'Data Science',
    'AI Programmer': 'AI',
    'AI Solution Architect': 'AI',
    'Data Operations Manager': 'Data Science',
    'Data Developer': 'Data Science',
    'Machine Learning Researcher': 'Machine Learning',
    'Cloud Database Engineer': 'Other',
    'ETL Developer': 'Other',
    'Machine Learning Specialist': 'Machine Learning',
    'NLP Engineer': 'AI',
    'Data Reporting Analyst': 'Data Science',
    'Business Intelligence Manager': 'Data Science',
    'Admin & Data Analyst': 'Data Science',
    'Business Intelligence Specialist': 'Data Science',
    'Data Analytics Associate': 'Data Science',
    'Head of Business Intelligence': 'Data Science',
    'Head of Machine Learning': 'Machine Learning',
    'Machine Learning Infrastructure Engineer': 'Machine Learning',
    'Data Visualization Engineer': 'Data Science',
    'Data Strategy Lead': 'Data Science',
    'Encounter Data Management Professional': 'Data Science',
    'ETL Engineer': 'Other',
    'AI Product Manager': 'AI',
    'AI Research Engineer': 'AI',
    'Data Management Associate': 'Data Science',
    'Data Quality Specialist': 'Data Science',
    'Business Intelligence Consultant': 'Data Science',
    'Robotics Software Engineer': 'Other',
    'Data Management Consultant': 'Data Science',
    'Data Analytics Consultant': 'Data Science',
    'Data Operations Associate': 'Data Science',
    'AI Data Scientist': 'AI',
    'Business Intelligence Lead': 'Data Science',
    'DataOps Engineer': 'Other',
    'AI Research Scientist': 'AI',
    'Data Visualization Developer': 'Data Science',
    'Data Integration Specialist': 'Data Science',
    'AI Software Engineer': 'AI',
    'Lead AI Engineer': 'AI',
    'AI Software Development Engineer': 'AI',
    'Master Data Specialist': 'Data Science',
    'Consultant Data Engineer': 'Data Science',
    'Manager Data Management': 'Data Science',
    'Director of Business Intelligence': 'Data Science',
    'Lead Data Scientist': 'Data Science',
    'Applied Research Scientist': 'AI',
    'CRM Data Analyst': 'Data Science',
    'BI Data Analyst': 'Data Science',
    'Applied Data Scientist': 'Data Science',
    'Computational Biologist': 'AI',
    'Big Data Engineer': 'Data Science',
    'Data DevOps Engineer': 'Other',
    'Big Data Developer': 'Other',
    'Quantitative Research Analyst': 'Data Science',
    'Lead Machine Learning Engineer': 'Machine Learning',
    'Machine Learning Research Engineer': 'Machine Learning',
    'Data Analyst Lead': 'Data Science',
    'Data Integration Developer': 'Data Science',
    'Data Pipeline Engineer': 'Data Science',
    'Lead Data Analyst': 'Data Science',
    'Business Data Analyst': 'Data Science',
    'Marketing Data Scientist': 'Data Science',
    'Deep Learning Engineer': 'AI',
    'Financial Data Analyst': 'Data Science',
    'Data Strategy Manager': 'Data Science',
    'Azure Data Engineer': 'Data Science',
    'Principal Data Scientist': 'Data Science',
    'Staff Data Analyst': 'Data Science',
    'Machine Learning Software Engineer': 'Machine Learning',
    'Applied Machine Learning Scientist': 'AI',
    'Principal Machine Learning Engineer': 'AI',
    'Principal Data Engineer': 'Data Science',
    'Power BI Developer': 'Data Science',
    'Staff Machine Learning Engineer': 'Machine Learning',
    'Staff Data Scientist': 'Data Science',
    'Business Intelligence Data Analyst': 'Data Science',
    'Finance Data Analyst': 'Data Science',
    'Software Data Engineer': 'Data Science',
    'Compliance Data Analyst': 'Data Science',
    'Cloud Data Engineer': 'Data Science',
    'Analytics Engineering Manager': 'Data Science',
    'AWS Data Architect': 'Data Science',
    'Product Data Analyst': 'Data Science',
    'Autonomous Vehicle Technician': 'Other',
    'Sales Data Analyst': 'Data Science',
    'Applied Machine Learning Engineer': 'AI',
    'BI Data Engineer': 'Data Science',
    'Deep Learning Researcher': 'Machine Learning',
    'Big Data Architect': 'Data Science',
    'Computer Vision Software Engineer': 'AI',
    'Marketing Data Engineer': 'Data Science',
    'Data Science Tech Lead': 'Data Science',
    'Data Scientist Lead': 'Data Science',
    'Marketing Data Analyst': 'Data Science',
    'Principal Data Architect': 'Data Science',
    'Data Analytics Engineer': 'Data Science',
    'Cloud Data Architect': 'Data Science',
    'Lead Data Engineer': 'Data Science',
    'Principal Data Analyst': 'Data Science'
}

# Map the job titles to groups
df['job_group'] = df['job_title'].map(job_title_mapping)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2908\1134654243.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_group'] = df['job_title'].map(job_title_mapping)
#        work_year experience_level employment_type                 job_title  \
# 0           2024               SE              FT              Data Analyst
# 1           2024               SE              FT              Data Analyst
# 2           2024               EX              FT         Software Engineer
# 3           2024               EX              FT         Software Engineer
# 4           2024               MI              FT              Data Manager
# ...          ...              ...             ...                       ...
# ...

# %%
# Check if any job titles are unmapped and handle them
unmapped_titles = df[df['job_group'].isnull()]['job_title'].unique()
print('Unmapped Titles:', unmapped_titles)
# Out:
# Unmapped Titles: []

# %%
# Get distinct company location
distinct_location = df['company_location'].unique()
distinct_location
# Out:
# array(['US', 'GB', 'CA', 'EG', 'DE', 'AM', 'BR', 'MX', 'FR', 'ZA', 'NZ',
#        'NL', 'SK', 'PL', 'AU', 'LT', 'PT', 'CL', 'AR', 'TR', 'IN', 'DZ',
#        'IE', 'IT', 'AS', 'IL', 'FI', 'LU', 'KE', 'RS', 'GR', 'UA', 'ES',
#        'SE', 'DK', 'LV', 'AT', 'CH', 'AE', 'SA', 'PH', 'OM', 'BA', 'EE',
#        'MT', 'HU', 'LB', 'RO', 'VN', 'NG', 'GI', 'CO', 'SI', 'MU', 'RU',
#        'KR', 'CZ', 'QA', 'GH', 'AD', 'EC', 'NO', 'JP', 'HK', 'CF', 'SG',
#        'TH', 'HR', 'PK', 'IR', 'BS', 'PR', 'BE', 'ID', 'MY', 'HN', 'IQ',
#        'CN', 'MD'], dtype=object)

# %%
# Dictionary mapping ISO country codes to regions
iso_to_region = {
    'US': 'North America', 'CA': 'North America', 'GB': 'Europe', 'IN': 'Asia', 'NZ': 'Oceania',
    'BR': 'South America', 'IE': 'Europe', 'NL': 'Europe', 'FR': 'Europe', 'ZA': 'Africa',
    'PH': 'Asia', 'AU': 'Oceania', 'IT': 'Europe', 'TR': 'Asia', 'EG': 'Africa',
    'AM': 'Asia', 'MX': 'North America', 'DE': 'Europe', 'SK': 'Europe', 'PL': 'Europe',
    'LT': 'Europe', 'PT': 'Europe', 'CL': 'South America', 'AR': 'South America', 'DZ': 'Africa',
    'AS': 'Oceania', 'IL': 'Asia', 'FI': 'Europe', 'LU': 'Europe', 'KE': 'Africa',
    'RS': 'Europe', 'GR': 'Europe', 'UA': 'Europe', 'ES': 'Europe', 'SE': 'Europe',
    'DK': 'Europe', 'LV': 'Europe', 'AT': 'Europe', 'CH': 'Europe', 'AE': 'Middle East',
    'SA': 'Middle East', 'OM': 'Middle East', 'BA': 'Europe', 'EE': 'Europe',
    'MT': 'Europe', 'HU': 'Europe', 'LB': 'Middle East', 'RO': 'Europe', 'VN': 'Asia',
    'NG': 'Africa', 'GI': 'Europe', 'CO': 'South America', 'SI': 'Europe', 'MU': 'Africa',
    'RU': 'Europe', 'KR': 'Asia', 'CZ': 'Europe', 'QA': 'Middle East', 'GH': 'Africa',
    'AD': 'Europe', 'EC': 'South America', 'NO': 'Europe', 'JP': 'Asia', 'HK': 'Asia',
    'CF': 'Africa', 'SG': 'Asia', 'TH': 'Asia', 'HR': 'Europe', 'PK': 'Asia', 'IR': 'Asia',
    'BS': 'North America', 'PR': 'North America', 'BE': 'Europe', 'ID': 'Asia', 'MY': 'Asia',
    'HN': 'North America', 'IQ': 'Middle East', 'CN': 'Asia', 'MD': 'Europe'
}

# Map the ISO codes to regions
df['Region'] = df['company_location'].map(iso_to_region)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2908\4284487926.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region'] = df['company_location'].map(iso_to_region)
#        work_year experience_level employment_type                 job_title  \
# 0           2024               SE              FT              Data Analyst
# 1           2024               SE              FT              Data Analyst
# 2           2024               EX              FT         Software Engineer
# 3           2024               EX              FT         Software Engineer
# 4           2024               MI              FT              Data Manager
# ...          ...              ...             ...                       ...
# ...

# %% [markdown]
# ## RESEARCH QUESTIONS
# ### Salary and Compensation
# #### 1. What is the average salary for AI, ML, and Data Science professionals worldwide
# #### And how does it compare across different job groups and experience levels?
# #### 2. What is the overall distribution of salaries?
# #### 3. What are the average, median, and mode of salary in USD?
# #### 4. What is the range (minimum and maximum) of salary irrespective of your job title or experience level?
#
#
# ### Geographic and Industry Analysis
# #### 1. Which regions offer the highest salaries for AI, ML, and Data Science roles
#
#
# ### Remote Work Trends
# #### 1. What percentage of AI, ML, and Data Science professionals are working remotely
# #### 2. Average salary of remote worker compare to in-office worker?
#
#
# ### Skills and Career Progression
# #### 1. What are the most in-demand skills in AI, ML, and Data Science
# #### 2. And how do they correlate with salary?
#
#
# ### Time-series analysis
# #### 1.How have salaries for AI, ML, and Data Science professionals evolved over the years,
# #### Keynote: what factors have influenced these changes?
# #### 2. Are there any trends in employment type or remote ratio over time?
# #### Insight: Helps professionals focus on acquiring valuable skills and assists organizations in identifying key competencies for hiring and development.
#
#
# ### Correlation and Advanced Analysis
# #### 1. Is there a correlation between experience level and salary?
# #### 2. Is there a correlation between company size and salary?
# #### 3. Is there any correlation between region and salaries
# #### 4. How do different factors (e.g., job title, experience level, company size) interact to influence salary?
#
#
# ### Stakeholders:
# #### Employees- salary ranges based on regions, companies etc
# #### Organizations- to establish salary comparisons, ranges, compensations etc
# #### Career transitioners- What is the market demand for professionals

# %%
#1. What is the average salary for AI, ML, and data science professionals worldwide?
avg_salary = df.groupby(['job_group', 'experience_level'])['salary_in_usd'].mean().reset_index()
avg_salary_pivot = avg_salary.pivot(index= 'experience_level', columns= 'job_group', values= 'salary_in_usd')
print("Average Salary by Job Groups and Experience Level:")
avg_salary_pivot
# Out:
# Average Salary by Job Groups and Experience Level:
# job_group                    AI   Data Science  Machine Learning  \
# experience_level
# EN                119818.652632   90884.344463     110314.573333
# EX                195580.428571  195016.272311     235065.527778
# MI                163015.683377  119359.681178     161147.997653
# SE                192451.988281  153392.827402     194097.319651
#
# job_group                 Other
# experience_level
# EN                121736.901961
# EX                196800.000000
# MI                171186.003155
# SE                189507.749591

# %%
#Plotting a line graph to show average salaries of job groups across experience levels
avg_salary_pivot.plot(kind='line',marker='*',figsize =(10,6))
plt.xlabel('job groups')
plt.ylabel('Average Salaries')
plt.grid(True)
plt.title('Analysis of average salaries of different job groups across experience levels')
plt.legend(title='Experience levels')
plt.show()

# %%
# 2. Overall Distribution of salaries
plt.figure(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], kde=True)
plt.title('Overall Distribution of Salaries')
plt.xlabel('salary_in_usd')
plt.ylabel('Frequency')
plt.show()

# %%
# 3. Average, median, and mode of salaries
avg_salary = df['salary_in_usd'].mean()
median_salary = df['salary_in_usd'].median()
mode_salary = df['salary_in_usd'].mode()[0]
print(f"Average Salary: ${avg_salary:.2f}")
print(f"Median Salary: ${median_salary:.2f}")
print(f"Mode Salary: ${mode_salary:.2f}")
# Out:
# Average Salary: $149539.10
# Median Salary: $140000.00
# Mode Salary: $100000.00

# %%
# 4. Range of salaries
min_salary = df['salary_in_usd'].min()
max_salary = df['salary_in_usd'].max()
print(f"Salary Range: ${min_salary:.2f} - ${max_salary:.2f}")
# Out:
# Salary Range: $15000.00 - $800000.00

# %%
# Geographic and Industry Analysis

# 1a. Regions offering the highest salaries and contributing factors
region_avg_salary = df.groupby(['Region', 'job_group'])['salary_in_usd'].mean().reset_index().sort_values(by='salary_in_usd', ascending=True)
region_avg_salary_pivot = region_avg_salary.pivot(index= 'Region', columns= 'job_group', values= 'salary_in_usd')
print("Average Salary by Company's Region")
region_avg_salary_pivot
# Out:
# Average Salary by Company's Region
# job_group                 AI   Data Science  Machine Learning          Other
# Region
# Africa          86858.500000   78131.292683      84516.400000   94047.333333
# Asia            88780.066667   48726.875000      66615.363636   41809.000000
# Europe          94022.354839   82045.199179     112321.500000  107695.342105
# Middle East    146712.000000   95699.600000      93750.000000            NaN
# North America  188113.561342  145270.412241     192286.200000  183994.204473
# Oceania         69981.833333  112243.092593     177820.250000  139876.500000
# South America   56616.166667   63154.000000      77930.000000  200000.000000

# %%
# Creating a Bar chart for average salary by region and job group
plt.figure(figsize=(14, 8))
sns.barplot(x='Region', y='salary_in_usd', hue='job_group', data= region_avg_salary)
plt.title("Average Salary by Company's Region and Job Group")
plt.xlabel('Region')
plt.ylabel('Average Salary')
plt.legend(title='Job Group')
plt.show()

# %%
# Filter the dataframe to only include AI,ML and Data Science professionals
ai_ml_ds_df = df[df['job_group'].isin(['AI', 'Machine Learning', 'Data Science'])]

ai_ml_ds_df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               SE              FT              Data Analyst
# 1           2024               SE              FT              Data Analyst
# 4           2024               MI              FT              Data Manager
# 5           2024               MI              FT              Data Manager
# 6           2024               MI              FT         Applied Scientist
# ...          ...              ...             ...                       ...
# 25755       2020               SE              FT            Data Scientist
# 25756       2021               MI              FT  Principal Data Scientist
# 25757       2020               EN              FT            Data Scientist
# 25758       2020               EN              CT     Business Data Analyst
# 25759       2021               SE              FT            Data Scientist
#
# ...

# %%
#Filtering dataframe to include AI, Machine Learning and Data Science professionals who work remotely
remote_worker = ai_ml_ds_df[ai_ml_ds_df['remote_ratio']== 100]
remote_worker
# Out:
#        work_year experience_level employment_type                 job_title  \
# 24          2024               SE              FT            Data Scientist
# 25          2024               SE              FT            Data Scientist
# 32          2024               SE              FT             Data Engineer
# 33          2024               SE              FT             Data Engineer
# 36          2024               MI              FT             Data Engineer
# ...          ...              ...             ...                       ...
# 25754       2021               SE              FT           Data Specialist
# 25755       2020               SE              FT            Data Scientist
# 25756       2021               MI              FT  Principal Data Scientist
# 25757       2020               EN              FT            Data Scientist
# 25758       2020               EN              CT     Business Data Analyst
#
# ...

# %%
#Knowing the value counts of those working remotely
remote_workers = remote_worker['job_group'].value_counts()

# %%
#Plot a pie chart to show percentage of AI, ML and Data Science profssionals working remotely
plt.figure(figsize=(10, 7))
plt.pie(remote_workers, labels=remote_workers.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Job Groups Working Remotely')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# 2. Comparism of professionals working remotely,hybrid and in-office and their average salary
remote_salary_comparison = df.groupby('remote_ratio')['salary_in_usd'].mean().reset_index()
remote_salary_comparison
# Out:
#    remote_ratio  salary_in_usd
# 0             0  153180.924611
# 1            50   82439.102767
# 2           100  145419.227459

# %%
#Skills and Career Progression
# What are the most in-demand skills in AI, ML, and data science
highest_skills = df['job_group'].value_counts()
print("From most to least demanded skills:")
highest_skills
# Out:
# From most to least demanded skills:
# job_group
# Data Science        10340
# Machine Learning     1682
# AI                   1263
# Other                 990
# Name: count, dtype: int64

# %%
#Plotting a pie chart showing the most demand skills
plt.figure(figsize=(10, 7))
plt.pie(highest_skills, labels=highest_skills.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Most Demand Skills')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Correlation with salary
skills_salary_correlation = df.explode('job_group').groupby('job_group')['salary_in_usd'].mean().reset_index().sort_values(by='salary_in_usd', ascending=False)
print("Job Title with Highest Average Salaries:")
print(skills_salary_correlation)
# Out:
# Job Title with Highest Average Salaries:
#           job_group  salary_in_usd
# 2  Machine Learning  182893.240190
# 3             Other  180230.888889
# 0                AI  178207.467933
# 1      Data Science  137673.075629

# %%
# Salary evolution over the years
salary_over_years = df.groupby('work_year')['salary_in_usd'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='work_year', y='salary_in_usd', data=salary_over_years)
plt.title('Salary Evolution Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Salary in USD')
plt.show()

# %%
# Calculate the percentage of each employment type by year
employment_type_counts = df.groupby(['work_year', 'employment_type']).size().reset_index(name='count')
total_count_per_year = df.groupby('work_year').size().reset_index(name='total_count')
employment_type_percentage = employment_type_counts.merge(total_count_per_year, on='work_year')
employment_type_percentage['percentage'] = (employment_type_percentage['count'] / employment_type_percentage['total_count']) * 100

# Visualize employment type trends over the years
plt.figure(figsize=(12, 6))
sns.barplot(data=employment_type_percentage, x='work_year', y='percentage', hue='employment_type')
plt.title('Employment Type Trends Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Employment Type')
plt.show()

# Calculate the percentage of remote work by year
remote_work_percentage_by_year = df.groupby(['work_year', 'remote_ratio']).size().reset_index(name='count')
remote_work_percentage_by_year = remote_work_percentage_by_year.merge(total_count_per_year, on='work_year')
remote_work_percentage_by_year['percentage'] = (remote_work_percentage_by_year['count'] / remote_work_percentage_by_year['total_count']) * 100

# Map remote_ratio to categorical labels for better visualization
remote_work_levels = {0: 'In-Office', 50: 'Hybrid', 100: 'Fully Remote'}
remote_work_percentage_by_year['remote_work_level'] = remote_work_percentage_by_year['remote_ratio'].map(remote_work_levels)

# Visualize remote work trends over the years
plt.figure(figsize=(12, 6))
sns.barplot(data=remote_work_percentage_by_year, x='work_year', y='percentage', hue='remote_work_level')
plt.title('Remote Work Trends Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage of Professionals Working Remotely')
plt.legend(title='Remote Work Level')
plt.show()

# %%
# Correlation and Advanced Analysis

# 1. Correlation between experience level and salaries
experience_salary_corr = df['experience_level'].astype('category').cat.codes.corr(df['salary_in_usd'])
print(f"Correlation between Experience Level and Salary: {experience_salary_corr:.2f}")
# Out:
# Correlation between Experience Level and Salary: 0.27

# %%
#what is the relationship between experience level and salaries
experience = df['experience_level']
salary_usd = df['salary_in_usd']

plt.scatter(experience, salary_usd, alpha = 0.5)
plt.xlabel('experience_level')
plt.ylabel('salary_in_usd')
plt.show()

# %%
# 2. Correlation between company size and salaries
company_size_salary_corr = df['company_size'].astype('category').cat.codes.corr(df['salary_in_usd'])
print(f"Correlation between Company Size and Salary: {company_size_salary_corr:.2f}")
# Out:
# Correlation between Company Size and Salary: 0.03

# %%
#what is the relationship between company size and salaries
company = df['company_size']
salary_usd = df['salary_in_usd']

plt.scatter(company, salary_usd, alpha = 0.5)
plt.xlabel('company_size')
plt.ylabel('salary_in_usd')
plt.show()

# %%
# 3. Correlation between region and salaries
region_salary_corr = df['Region'].astype('category').cat.codes.corr(df['salary_in_usd'])
print(f"Correlation between Company_location and Salary: {region_salary_corr:.2f}")
# Out:
# Correlation between Company_location and Salary: 0.27

# %%
#what is the relationship between region and salaries
location = df['Region']
salary_usd = df['salary_in_usd']

plt.scatter(location, salary_usd, alpha = 0.5)
plt.xlabel('company_size')
plt.ylabel('salary_in_usd')
plt.show()

# %%
# 4. Interaction of factors influencing salary
# How do different factors (e.g., job group, experience level, company size and location) interact to influence salary?
interaction_factors = df[['salary_in_usd', 'experience_level', 'company_size', 'Region', 'job_group']]

# Convert categorical variables to numerical
interaction_factors['experience_level'] = interaction_factors['experience_level'].astype('category').cat.codes
interaction_factors['company_size'] = interaction_factors['company_size'].astype('category').cat.codes
interaction_factors['Region'] = interaction_factors['Region'].astype('category').cat.codes
interaction_factors['job_group'] = interaction_factors['job_group'].astype('category').cat.codes

plt.figure(figsize=(10, 6))
sns.heatmap(interaction_factors.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Factors Influencing Salary')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2908\2763452156.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interaction_factors['experience_level'] = interaction_factors['experience_level'].astype('category').cat.codes
# C:\Users\USER\AppData\Local\Temp\ipykernel_2908\2763452156.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interaction_factors['company_size'] = interaction_factors['company_size'].astype('category').cat.codes
# ...

# %% [markdown]
# # OBSERVATION
#
# ### ** From the analysis we have carried out, it has been observed that:
# ### ** Machine Learning professionals has the highest average salary at the Executive, Senior-level and Mid-level.
# ### ** North America offers the highest salary for both AI, Machine Learning and Data Science professions while Aisa offers the least
# ### ** Data Science group has the highest number of those working remotely, 80% of the remote population are from Data Science while AI was the least.
# ### ** The dataset shows that Data Science job group are most demand skills in the labour market.
# ### ** Analysis of salaries over the years shows that there have been high increase over time.
# ### ** Full-time employment is more practiced than other types of employment and there is more of in-office workers than those working remotely.
# ### ** Experience, job groups and company’s location are some factors that determine salary while company size doesn’t influences salary

# %% [markdown]
# # RECOMMENDATION
#
# ### ** For those starting their Tech career, they can explore other fields like AI and Machince Learning to avoid oversaturation of the Data Science field
# ### ** It is important to improve your skills as if influences the salary to be paid.
